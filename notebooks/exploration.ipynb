# %%
import numpy as np
import scipy as sp

# %%
# Q1. Image batch
X = np.random.rand(4, 3, 8, 8).astype(np.float32)
# (B=4, C=3, H=8, W=8)
print("X.shape:", X.shape)
print("X.strides:", X.strides)
# Question: What does each stride value represent in BYTES?
# Calculate manually and verify!
# 768: Bytes to jump to the next batch
# 256: Bytes to jump to the next channel
# 32: Bytes to jump to the next row (height)
# 4: Bytes to jump to the next column (width)
# Out:
# X.shape: (4, 3, 8, 8)
# X.strides: (768, 256, 32, 4)

# %%
# Q2. Extract 2x2 patches, with a stride of 1
X = np.random.rand(1, 1, 4, 4).astype(np.float32)
# (B=1, C=1, H=4, W=4)

# Goal: Extract ALL 2×2 patches with stride=1
# Expected output shape: (1, 3, 3, 2, 2, 1)
#                         B  H_out W_out kH kW C
# Out:
# (1, 3, 3, 2, 2, 1)
